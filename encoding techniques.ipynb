# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.DataFrame({'Temp':['Hot','Cold','Warm','Very Cold','Hot','Cold','Very Hot','Hot','Warm','Hot'],
      'Color':['Red','Blue','Yellow','Yellow','Blue','Red','Blue','Blue','Yellow','Red']})

# %%
df.head()
# Out:
#         Temp   Color
# 0        Hot     Red
# 1       Cold    Blue
# 2       Warm  Yellow
# 3  Very Cold  Yellow
# 4        Hot    Blue

# %% [markdown]
# ### Handling ordinal data

# %%
# Encoding based on hierarchy

res = {'Very Cold':1, 'Cold': 2, 'Warm': 3, 'Hot': 4, 'Very Hot': 5 }
df['Ordinal_Encoded_Temp'] = df['Temp'].map(res)

# %%
df
# Out:
#         Temp   Color  Ordinal_Encoded_Temp
# 0        Hot     Red                     4
# 1       Cold    Blue                     2
# 2       Warm  Yellow                     3
# 3  Very Cold  Yellow                     1
# 4        Hot    Blue                     4
# 5       Cold     Red                     2
# 6   Very Hot    Blue                     5
# 7        Hot    Blue                     4
# 8       Warm  Yellow                     3
# 9        Hot     Red                     4

# %%
# Encoding using label encoding

LE = LabelEncoder()
df['Label_Encoded_color'] = LE.fit_transform(df['Color'])

# %%
# Using one hot encoding

df = pd.get_dummies(df,columns=['Color'])

# %%
df
# Out:
#         Temp  Ordinal_Encoded_Temp  Label_Encoded_color  Color_Blue  \
# 0        Hot                     4                    1           0
# 1       Cold                     2                    0           1
# 2       Warm                     3                    2           0
# 3  Very Cold                     1                    2           0
# 4        Hot                     4                    0           1
# 5       Cold                     2                    1           0
# 6   Very Hot                     5                    0           1
# 7        Hot                     4                    0           1
# 8       Warm                     3                    2           0
# 9        Hot                     4                    1           0
#
#    Color_Red  Color_Yellow
# 0          1             0
# 1          0             0
# 2          0             1
# 3          0             1
# 4          0             0
# 5          1             0
# 6          0             0
# 7          0             0
# 8          0             1
# 9          1             0

# %% [markdown]
# ### Practicing the encoding techniuqes using sklearn, pandas, category_encoders

# %%
df1 = pd.DataFrame({'Temperature': ['Hot', 'Cold', 'Very Hot','Warm','Hot','Warm','Warm','Hot','Hot','Cold'],
                    'Color':['Red','Yellow','Blue','Blue','Red','Yellow','Red','Yellow','Yellow','Yellow'],
                    'Target': [1,1,1,0,1,0,1,0,1,1]},
                     columns = ['Temperature', 'Color', 'Target'])

# %%
df1
# Out:
#   Temperature   Color  Target
# 0         Hot     Red       1
# 1        Cold  Yellow       1
# 2    Very Hot    Blue       1
# 3        Warm    Blue       0
# 4         Hot     Red       1
# 5        Warm  Yellow       0
# 6        Warm     Red       1
# 7         Hot  Yellow       0
# 8         Hot  Yellow       1
# 9        Cold  Yellow       1

# %% [markdown]
# #### One Hot Encoding

# %%
# using pandas get_dummies

df1 = pd.get_dummies(df1, prefix='Temp', columns=['Temperature'])
df1
# Out:
#     Color  Target  Temp_Cold  Temp_Hot  Temp_Very Hot  Temp_Warm
# 0     Red       1          0         1              0          0
# 1  Yellow       1          1         0              0          0
# 2    Blue       1          0         0              1          0
# 3    Blue       0          0         0              0          1
# 4     Red       1          0         1              0          0
# 5  Yellow       0          0         0              0          1
# 6     Red       1          0         0              0          1
# 7  Yellow       0          0         1              0          0
# 8  Yellow       1          0         1              0          0
# 9  Yellow       1          1         0              0          0

# %%
'''Using scikit learn preprocessing tools (OneHotEncoder)--- this method does not create additional
column unlike the pandas get_dummies method'''

from sklearn.preprocessing import OneHotEncoder
df = pd.DataFrame({'Temperature': ['Hot', 'Cold', 'Very Hot','Warm','Hot','Warm','Warm','Hot','Hot','Cold'],
                    'Color':['Red','Yellow','Blue','Blue','Red','Yellow','Red','Yellow','Yellow','Yellow'],},
                     columns = ['Temperature', 'Color'])


# ohc = OneHotEncoder()
# ohe = ohc.fit_transform(df, )

# %%
df['Temperature'].values.reshape(-1,1).toarray()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-5370460c1dcc> in <module>()
# ----> 1 df['Temperature'].values.reshape(-1,1).toarray()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'toarray'
